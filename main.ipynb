# %% [markdown]
# ### Import first

# %%
# %run GUI.ipynb

# %% [markdown]
# # Basic Processing part

# %% [markdown]
# ## choose image

# %%
display(interactive_full_box_basic_input)
# Out:
# ...
# Your choice: 05_h.jpg

# %% [markdown]
# ## Start processing

# %%
display(start_basicProcessing_button)
# Out:
# Button(description='Start processing', style=ButtonStyle(button_color='lightpink'))
# Starting processing...

# %% [markdown]
# ## Show statistic

# %%
display(show_stats_basicProcessing_button)
# Out:
# Button(description='Show statistics', style=ButtonStyle(button_color='lightpink'))
# Accuracy: 0.954972
# Sensitivity: 0.753889
# Specificity: 0.972395
# Geo mean metric: 0.856200

# %% [markdown]
# # KNN part

# %% [markdown]
# ## choose learnig set

# %%
display(interactive_full_box_learning_set)
# Out:
# ...
# Your choice: ('Image_01L.jpg', 'Image_01R.jpg', 'Image_02L.jpg', 'Image_02R.jpg', 'Image_03L.jpg', 'Image_03R.jpg', 'Image_04L.jpg', 'Image_04R.jpg', 'Image_05L.jpg', 'Image_05R.jpg', 'Image_06L.jpg', 'Image_06R.jpg', 'Image_07L.jpg', 'Image_07R.jpg', 'Image_08L.jpg', 'Image_08R.jpg', 'Image_09L.jpg', 'Image_09R.jpg', 'Image_10L.jpg', 'Image_10R.jpg', 'Image_11L.jpg', 'Image_11R.jpg', 'Image_12L.jpg', 'Image_12R.jpg')
# [INFO] histogram accuracy: 76.39%

# %% [markdown]
# ## choose image

# %%
display(interactive_full_box_knn_processing)
# Out:
# ...
# 956 / 956 Time: 189.79

# %% [markdown]
# ## Show statistic

# %%
display(show_stats_knn)
# Out:
# Button(description='Show statistics', style=ButtonStyle(button_color='lightpink'))
# Accuracy: 0.885911
# Sensitivity: 0.638664
# Specificity: 0.910082
# Geo mean metric: 0.762389

# %% [markdown]
# # Deep Learnig part

# %% [markdown]
# ## choose model

# %%
display(interactive_full_box_choose_model_file)
# Out:
# ...
# models/small_bs4_450/ Unet_purple_background7.h5 Image_13L.jpg

# %% [markdown]
# ## Show statistic

# %%
display(show_stats_ML)
# Out:
# Button(description='Show statistics', style=ButtonStyle(button_color='lightpink'))
# Accuracy: 0.927959
# Sensitivity: 0.610249
# Specificity: 0.971038
# Geo mean metric: 0.769789
